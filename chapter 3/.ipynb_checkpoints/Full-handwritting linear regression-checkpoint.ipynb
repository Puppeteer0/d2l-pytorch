# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# Dataset

# %%
"generation paradigm:y = Xw + b + ϵ(w =(2,-3.4)T、b = 4.2)."
def synthetic_data(w, b, num_examples): #@save
    """⽣成y=Xw+b+噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))#生成正态分布数据集
    y = torch.matmul(X, w) + b#高维矩阵乘法
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print(features.shape,labels.shape)
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# torch.Size([1000, 2]) torch.Size([1000, 1])
# features: tensor([ 0.7325, -0.4294])
# label: tensor([7.1209])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %%
def data_iter(batch_size, features, labels):#随机抽取batch_size大小的数据出来
    num_examples = len(features)
    indices = list(range(num_examples))#生成一个序列表
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i: min(i + batch_size, num_examples)])
        yield features[batch_indices], labels[batch_indices]

# %%
batch_size = 10
for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    break
# Out:
# tensor([[-0.8639,  0.4594],
#         [ 0.9302,  0.9665],
#         [ 0.0456,  0.7325],
#         [ 0.0230, -0.3417],
#         [-1.0611,  0.6506],
#         [ 0.4267,  0.0477],
#         [ 0.9394,  1.3298],
#         [ 0.9538, -0.8736],
#         [-0.3762, -0.6166],
#         [ 0.6554,  0.5761]])
#  tensor([[ 0.9248],
#         [ 2.7778],
#         [ 1.8160],
#         [ 5.4039],
#         [-0.1297],
#         [ 4.9085],
#         [ 1.5531],
#         [ 9.0820],
#         [ 5.5425],
#         [ 3.5504]])

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)#初始化权重+自动微分
b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# Model

# %%
def linreg(X, w, b): #@save
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %%
def squared_loss(y_hat, y): #@save #损失函数，均方差
    """均⽅损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %%
def SGD(params, lr, batch_size): #@save #自定义优化函数
    """⼩批量随机梯度下降"""
    with torch.no_grad():#关闭自动求梯度
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %% [markdown]
# Train

# %%
lr = 0.03 #设置超参数
num_epochs = 3
net = linreg
loss = squared_loss

# %%
print(w)
for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        print(w)
        l = loss(net(X, w, b), y) # X和y的⼩批量损失
        # 因为l形状是(batch_size,1)，⽽不是⼀个标量。l中的所有元素被加到⼀起，并以此计算关于[w,b]的梯度
        l.sum().backward()
        SGD([w, b], lr, batch_size) # 使⽤参数的梯度更新参数
    print(w)
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
    print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# tensor([[-0.0136],
#         [ 0.0006]], requires_grad=True)
# tensor([[-0.0136],
#         [ 0.0006]], requires_grad=True)
# tensor([[ 0.0179],
#         [-0.1180]], requires_grad=True)
# tensor([[ 0.0943],
#         [-0.2175]], requires_grad=True)
# tensor([[ 0.1611],
#         [-0.2423]], requires_grad=True)
# tensor([[ 0.1189],
#         [-0.3843]], requires_grad=True)
# tensor([[ 0.1056],
#         [-0.4695]], requires_grad=True)
# tensor([[ 0.1147],
#         [-0.5091]], requires_grad=True)
# tensor([[ 0.1664],
#         [-0.5594]], requires_grad=True)
# tensor([[ 0.1453],
#         [-0.7352]], requires_grad=True)
# tensor([[ 0.1496],
#         [-0.8217]], requires_grad=True)
# tensor([[ 0.3856],
#         [-0.9040]], requires_grad=True)
# tensor([[ 0.3837],
#         [-1.0063]], requires_grad=True)
# tensor([[ 0.3989],
#         [-1.1233]], requires_grad=True)
# tensor([[ 0.4391],
#         [-1.1248]], requires_grad=True)
# tensor([[ 0.5344],
#         [-1.1822]], requires_grad=True)
# tensor([[ 0.5938],
#         [-1.2426]], requires_grad=True)
# tensor([[ 0.5999],
#         [-1.3472]], requires_grad=True)
# tensor([[ 0.6204],
#         [-1.3939]], requires_grad=True)
# tensor([[ 0.6785],
#         [-1.5028]], requires_grad=True)
# tensor([[ 0.7356],
#         [-1.5184]], requires_grad=True)
# tensor([[ 0.8000],
#         [-1.5296]], requires_grad=True)
# tensor([[ 0.8186],
#         [-1.6159]], requires_grad=True)
# tensor([[ 0.9074],
#         [-1.7830]], requires_grad=True)
# tensor([[ 0.9670],
#         [-1.8316]], requires_grad=True)
# tensor([[ 1.0226],
#         [-1.9136]], requires_grad=True)
# tensor([[ 1.0927],
#         [-1.9540]], requires_grad=True)
# tensor([[ 1.0899],
#         [-2.0228]], requires_grad=True)
# tensor([[ 1.1170],
#         [-2.0703]], requires_grad=True)
# tensor([[ 1.1644],
#         [-2.1199]], requires_grad=True)
# tensor([[ 1.1841],
#         [-2.1490]], requires_grad=True)
# tensor([[ 1.1878],
#         [-2.1794]], requires_grad=True)
# tensor([[ 1.2025],
#         [-2.2211]], requires_grad=True)
# tensor([[ 1.2382],
#         [-2.2533]], requires_grad=True)
# tensor([[ 1.2339],
#         [-2.2607]], requires_grad=True)
# tensor([[ 1.2672],
#         [-2.2773]], requires_grad=True)
# tensor([[ 1.2912],
#         [-2.3124]], requires_grad=True)
# tensor([[ 1.3127],
#         [-2.3270]], requires_grad=True)
# tensor([[ 1.3269],
#         [-2.3451]], requires_grad=True)
# tensor([[ 1.3454],
#         [-2.3593]], requires_grad=True)
# tensor([[ 1.3386],
#         [-2.3946]], requires_grad=True)
# tensor([[ 1.3546],
#         [-2.4121]], requires_grad=True)
# tensor([[ 1.3784],
#         [-2.4221]], requires_grad=True)
# tensor([[ 1.3931],
#         [-2.4487]], requires_grad=True)
# tensor([[ 1.3810],
#         [-2.4656]], requires_grad=True)
# tensor([[ 1.4068],
#         [-2.4994]], requires_grad=True)
# tensor([[ 1.4037],
#         [-2.5634]], requires_grad=True)
# tensor([[ 1.3886],
#         [-2.6163]], requires_grad=True)
# tensor([[ 1.3948],
#         [-2.6476]], requires_grad=True)
# tensor([[ 1.4100],
#         [-2.6848]], requires_grad=True)
# tensor([[ 1.4375],
#         [-2.7147]], requires_grad=True)
# tensor([[ 1.4628],
#         [-2.7315]], requires_grad=True)
# tensor([[ 1.4885],
#         [-2.7398]], requires_grad=True)
# tensor([[ 1.4973],
#         [-2.7483]], requires_grad=True)
# tensor([[ 1.5083],
#         [-2.7481]], requires_grad=True)
# tensor([[ 1.5216],
#         [-2.7590]], requires_grad=True)
# tensor([[ 1.5424],
#         [-2.7894]], requires_grad=True)
# tensor([[ 1.5510],
#         [-2.8015]], requires_grad=True)
# tensor([[ 1.5682],
#         [-2.8290]], requires_grad=True)
# tensor([[ 1.5682],
#         [-2.8362]], requires_grad=True)
# tensor([[ 1.5775],
#         [-2.8518]], requires_grad=True)
# tensor([[ 1.5874],
#         [-2.8632]], requires_grad=True)
# tensor([[ 1.6018],
#         [-2.8678]], requires_grad=True)
# tensor([[ 1.6042],
#         [-2.9170]], requires_grad=True)
# tensor([[ 1.6169],
#         [-2.9244]], requires_grad=True)
# tensor([[ 1.6216],
#         [-2.9314]], requires_grad=True)
# tensor([[ 1.6254],
#         [-2.9650]], requires_grad=True)
# tensor([[ 1.6334],
#         [-2.9735]], requires_grad=True)
# tensor([[ 1.6391],
#         [-2.9908]], requires_grad=True)
# tensor([[ 1.6442],
#         [-2.9900]], requires_grad=True)
# tensor([[ 1.6507],
#         [-3.0275]], requires_grad=True)
# tensor([[ 1.6605],
#         [-3.0379]], requires_grad=True)
# tensor([[ 1.6893],
#         [-3.0558]], requires_grad=True)
# tensor([[ 1.6957],
#         [-3.0904]], requires_grad=True)
# tensor([[ 1.7136],
#         [-3.1074]], requires_grad=True)
# tensor([[ 1.7232],
#         [-3.1302]], requires_grad=True)
# tensor([[ 1.7281],
#         [-3.1496]], requires_grad=True)
# tensor([[ 1.7369],
#         [-3.1610]], requires_grad=True)
# tensor([[ 1.7457],
#         [-3.1719]], requires_grad=True)
# tensor([[ 1.7499],
#         [-3.1774]], requires_grad=True)
# tensor([[ 1.7604],
#         [-3.1835]], requires_grad=True)
# tensor([[ 1.7742],
#         [-3.1865]], requires_grad=True)
# tensor([[ 1.7778],
#         [-3.2044]], requires_grad=True)
# tensor([[ 1.7851],
#         [-3.2159]], requires_grad=True)
# tensor([[ 1.7928],
#         [-3.2215]], requires_grad=True)
# tensor([[ 1.7985],
#         [-3.2303]], requires_grad=True)
# tensor([[ 1.8092],
#         [-3.2259]], requires_grad=True)
# tensor([[ 1.8097],
#         [-3.2281]], requires_grad=True)
# tensor([[ 1.8127],
#         [-3.2289]], requires_grad=True)
# tensor([[ 1.8166],
#         [-3.2305]], requires_grad=True)
# tensor([[ 1.8257],
#         [-3.2404]], requires_grad=True)
# tensor([[ 1.8302],
#         [-3.2471]], requires_grad=True)
# tensor([[ 1.8386],
#         [-3.2473]], requires_grad=True)
# tensor([[ 1.8413],
#         [-3.2490]], requires_grad=True)
# tensor([[ 1.8476],
#         [-3.2524]], requires_grad=True)
# tensor([[ 1.8475],
#         [-3.2596]], requires_grad=True)
# tensor([[ 1.8540],
#         [-3.2664]], requires_grad=True)
# tensor([[ 1.8567],
#         [-3.2703]], requires_grad=True)
# tensor([[ 1.8571],
#         [-3.2736]], requires_grad=True)
# tensor([[ 1.8595],
#         [-3.2762]], requires_grad=True)
# tensor([[ 1.8609],
#         [-3.2787]], requires_grad=True)
# tensor([[ 1.8629],
#         [-3.2820]], requires_grad=True)
# epoch 1, loss 0.034442
# tensor([[ 1.8629],
#         [-3.2820]], requires_grad=True)
# tensor([[ 1.8674],
#         [-3.2873]], requires_grad=True)
# tensor([[ 1.8703],
#         [-3.2909]], requires_grad=True)
# tensor([[ 1.8728],
#         [-3.2932]], requires_grad=True)
# tensor([[ 1.8748],
#         [-3.2974]], requires_grad=True)
# tensor([[ 1.8795],
#         [-3.3017]], requires_grad=True)
# tensor([[ 1.8835],
#         [-3.3064]], requires_grad=True)
# tensor([[ 1.8873],
#         [-3.3120]], requires_grad=True)
# tensor([[ 1.8884],
#         [-3.3130]], requires_grad=True)
# tensor([[ 1.8877],
#         [-3.3134]], requires_grad=True)
# tensor([[ 1.8912],
#         [-3.3133]], requires_grad=True)
# tensor([[ 1.8945],
#         [-3.3227]], requires_grad=True)
# tensor([[ 1.8996],
#         [-3.3250]], requires_grad=True)
# tensor([[ 1.9037],
#         [-3.3252]], requires_grad=True)
# tensor([[ 1.9053],
#         [-3.3251]], requires_grad=True)
# tensor([[ 1.9066],
#         [-3.3282]], requires_grad=True)
# tensor([[ 1.9107],
#         [-3.3308]], requires_grad=True)
# tensor([[ 1.9121],
#         [-3.3309]], requires_grad=True)
# tensor([[ 1.9125],
#         [-3.3308]], requires_grad=True)
# tensor([[ 1.9140],
#         [-3.3333]], requires_grad=True)
# tensor([[ 1.9156],
#         [-3.3353]], requires_grad=True)
# tensor([[ 1.9168],
#         [-3.3355]], requires_grad=True)
# tensor([[ 1.9186],
#         [-3.3376]], requires_grad=True)
# tensor([[ 1.9202],
#         [-3.3393]], requires_grad=True)
# tensor([[ 1.9228],
#         [-3.3409]], requires_grad=True)
# tensor([[ 1.9260],
#         [-3.3446]], requires_grad=True)
# tensor([[ 1.9297],
#         [-3.3469]], requires_grad=True)
# tensor([[ 1.9326],
#         [-3.3544]], requires_grad=True)
# tensor([[ 1.9339],
#         [-3.3577]], requires_grad=True)
# tensor([[ 1.9357],
#         [-3.3590]], requires_grad=True)
# tensor([[ 1.9368],
#         [-3.3604]], requires_grad=True)
# tensor([[ 1.9381],
#         [-3.3631]], requires_grad=True)
# tensor([[ 1.9395],
#         [-3.3648]], requires_grad=True)
# tensor([[ 1.9409],
#         [-3.3646]], requires_grad=True)
# tensor([[ 1.9421],
#         [-3.3653]], requires_grad=True)
# tensor([[ 1.9452],
#         [-3.3649]], requires_grad=True)
# tensor([[ 1.9457],
#         [-3.3665]], requires_grad=True)
# tensor([[ 1.9470],
#         [-3.3669]], requires_grad=True)
# tensor([[ 1.9480],
#         [-3.3700]], requires_grad=True)
# tensor([[ 1.9487],
#         [-3.3704]], requires_grad=True)
# tensor([[ 1.9507],
#         [-3.3716]], requires_grad=True)
# tensor([[ 1.9512],
#         [-3.3730]], requires_grad=True)
# tensor([[ 1.9529],
#         [-3.3742]], requires_grad=True)
# tensor([[ 1.9532],
#         [-3.3746]], requires_grad=True)
# tensor([[ 1.9560],
#         [-3.3755]], requires_grad=True)
# tensor([[ 1.9574],
#         [-3.3762]], requires_grad=True)
# tensor([[ 1.9613],
#         [-3.3765]], requires_grad=True)
# tensor([[ 1.9619],
#         [-3.3777]], requires_grad=True)
# tensor([[ 1.9635],
#         [-3.3782]], requires_grad=True)
# tensor([[ 1.9653],
#         [-3.3791]], requires_grad=True)
# tensor([[ 1.9654],
#         [-3.3799]], requires_grad=True)
# tensor([[ 1.9665],
#         [-3.3802]], requires_grad=True)
# tensor([[ 1.9671],
#         [-3.3806]], requires_grad=True)
# tensor([[ 1.9676],
#         [-3.3807]], requires_grad=True)
# tensor([[ 1.9684],
#         [-3.3813]], requires_grad=True)
# tensor([[ 1.9697],
#         [-3.3822]], requires_grad=True)
# tensor([[ 1.9700],
#         [-3.3826]], requires_grad=True)
# tensor([[ 1.9714],
#         [-3.3850]], requires_grad=True)
# tensor([[ 1.9723],
#         [-3.3845]], requires_grad=True)
# tensor([[ 1.9725],
#         [-3.3846]], requires_grad=True)
# tensor([[ 1.9737],
#         [-3.3865]], requires_grad=True)
# tensor([[ 1.9747],
#         [-3.3871]], requires_grad=True)
# tensor([[ 1.9753],
#         [-3.3872]], requires_grad=True)
# tensor([[ 1.9760],
#         [-3.3878]], requires_grad=True)
# tensor([[ 1.9768],
#         [-3.3885]], requires_grad=True)
# tensor([[ 1.9771],
#         [-3.3888]], requires_grad=True)
# tensor([[ 1.9776],
#         [-3.3894]], requires_grad=True)
# tensor([[ 1.9779],
#         [-3.3904]], requires_grad=True)
# tensor([[ 1.9783],
#         [-3.3902]], requires_grad=True)
# tensor([[ 1.9795],
#         [-3.3902]], requires_grad=True)
# tensor([[ 1.9797],
#         [-3.3902]], requires_grad=True)
# tensor([[ 1.9803],
#         [-3.3899]], requires_grad=True)
# tensor([[ 1.9808],
#         [-3.3906]], requires_grad=True)
# tensor([[ 1.9814],
#         [-3.3908]], requires_grad=True)
# tensor([[ 1.9818],
#         [-3.3908]], requires_grad=True)
# tensor([[ 1.9821],
#         [-3.3909]], requires_grad=True)
# tensor([[ 1.9824],
#         [-3.3912]], requires_grad=True)
# tensor([[ 1.9828],
#         [-3.3911]], requires_grad=True)
# tensor([[ 1.9833],
#         [-3.3913]], requires_grad=True)
# tensor([[ 1.9841],
#         [-3.3916]], requires_grad=True)
# tensor([[ 1.9844],
#         [-3.3918]], requires_grad=True)
# tensor([[ 1.9852],
#         [-3.3923]], requires_grad=True)
# tensor([[ 1.9856],
#         [-3.3929]], requires_grad=True)
# tensor([[ 1.9870],
#         [-3.3925]], requires_grad=True)
# tensor([[ 1.9879],
#         [-3.3929]], requires_grad=True)
# tensor([[ 1.9882],
#         [-3.3930]], requires_grad=True)
# tensor([[ 1.9884],
#         [-3.3937]], requires_grad=True)
# tensor([[ 1.9889],
#         [-3.3937]], requires_grad=True)
# tensor([[ 1.9892],
#         [-3.3939]], requires_grad=True)
# tensor([[ 1.9894],
#         [-3.3940]], requires_grad=True)
# tensor([[ 1.9898],
#         [-3.3943]], requires_grad=True)
# tensor([[ 1.9899],
#         [-3.3942]], requires_grad=True)
# tensor([[ 1.9900],
#         [-3.3943]], requires_grad=True)
# tensor([[ 1.9901],
#         [-3.3947]], requires_grad=True)
# tensor([[ 1.9902],
#         [-3.3951]], requires_grad=True)
# tensor([[ 1.9905],
#         [-3.3950]], requires_grad=True)
# tensor([[ 1.9908],
#         [-3.3945]], requires_grad=True)
# tensor([[ 1.9911],
#         [-3.3948]], requires_grad=True)
# tensor([[ 1.9912],
#         [-3.3950]], requires_grad=True)
# tensor([[ 1.9914],
#         [-3.3950]], requires_grad=True)
# tensor([[ 1.9918],
#         [-3.3949]], requires_grad=True)
# epoch 2, loss 0.000137
# tensor([[ 1.9918],
#         [-3.3949]], requires_grad=True)
# tensor([[ 1.9920],
#         [-3.3951]], requires_grad=True)
# tensor([[ 1.9922],
#         [-3.3953]], requires_grad=True)
# tensor([[ 1.9924],
#         [-3.3954]], requires_grad=True)
# tensor([[ 1.9927],
#         [-3.3953]], requires_grad=True)
# tensor([[ 1.9931],
#         [-3.3954]], requires_grad=True)
# tensor([[ 1.9932],
#         [-3.3954]], requires_grad=True)
# tensor([[ 1.9934],
#         [-3.3955]], requires_grad=True)
# tensor([[ 1.9935],
#         [-3.3958]], requires_grad=True)
# tensor([[ 1.9937],
#         [-3.3959]], requires_grad=True)
# tensor([[ 1.9938],
#         [-3.3959]], requires_grad=True)
# tensor([[ 1.9939],
#         [-3.3962]], requires_grad=True)
# tensor([[ 1.9942],
#         [-3.3963]], requires_grad=True)
# tensor([[ 1.9942],
#         [-3.3963]], requires_grad=True)
# tensor([[ 1.9943],
#         [-3.3963]], requires_grad=True)
# tensor([[ 1.9944],
#         [-3.3965]], requires_grad=True)
# tensor([[ 1.9944],
#         [-3.3965]], requires_grad=True)
# tensor([[ 1.9945],
#         [-3.3966]], requires_grad=True)
# tensor([[ 1.9945],
#         [-3.3967]], requires_grad=True)
# tensor([[ 1.9946],
#         [-3.3966]], requires_grad=True)
# tensor([[ 1.9947],
#         [-3.3967]], requires_grad=True)
# tensor([[ 1.9947],
#         [-3.3968]], requires_grad=True)
# tensor([[ 1.9949],
#         [-3.3970]], requires_grad=True)
# tensor([[ 1.9949],
#         [-3.3970]], requires_grad=True)
# tensor([[ 1.9950],
#         [-3.3972]], requires_grad=True)
# tensor([[ 1.9953],
#         [-3.3972]], requires_grad=True)
# tensor([[ 1.9953],
#         [-3.3973]], requires_grad=True)
# tensor([[ 1.9954],
#         [-3.3974]], requires_grad=True)
# tensor([[ 1.9954],
#         [-3.3977]], requires_grad=True)
# tensor([[ 1.9955],
#         [-3.3976]], requires_grad=True)
# tensor([[ 1.9956],
#         [-3.3975]], requires_grad=True)
# tensor([[ 1.9959],
#         [-3.3976]], requires_grad=True)
# tensor([[ 1.9960],
#         [-3.3975]], requires_grad=True)
# tensor([[ 1.9961],
#         [-3.3976]], requires_grad=True)
# tensor([[ 1.9965],
#         [-3.3977]], requires_grad=True)
# tensor([[ 1.9967],
#         [-3.3979]], requires_grad=True)
# tensor([[ 1.9968],
#         [-3.3979]], requires_grad=True)
# tensor([[ 1.9968],
#         [-3.3979]], requires_grad=True)
# tensor([[ 1.9970],
#         [-3.3978]], requires_grad=True)
# tensor([[ 1.9972],
#         [-3.3976]], requires_grad=True)
# tensor([[ 1.9972],
#         [-3.3978]], requires_grad=True)
# tensor([[ 1.9974],
#         [-3.3978]], requires_grad=True)
# tensor([[ 1.9976],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9976],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9977],
#         [-3.3981]], requires_grad=True)
# tensor([[ 1.9976],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9979],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9979],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9978],
#         [-3.3981]], requires_grad=True)
# tensor([[ 1.9979],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9980],
#         [-3.3979]], requires_grad=True)
# tensor([[ 1.9981],
#         [-3.3980]], requires_grad=True)
# tensor([[ 1.9980],
#         [-3.3982]], requires_grad=True)
# tensor([[ 1.9983],
#         [-3.3982]], requires_grad=True)
# tensor([[ 1.9985],
#         [-3.3982]], requires_grad=True)
# tensor([[ 1.9985],
#         [-3.3982]], requires_grad=True)
# tensor([[ 1.9987],
#         [-3.3984]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3984]], requires_grad=True)
# tensor([[ 1.9987],
#         [-3.3984]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3985]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3986]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3986]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3987]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3988]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3987]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3987]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3988]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3988]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3989]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3991]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9987],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9987],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9988],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9989],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3996]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3996]], requires_grad=True)
# tensor([[ 1.9991],
#         [-3.3997]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3998]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3997]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3996]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3996]], requires_grad=True)
# tensor([[ 1.9991],
#         [-3.3993]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3993]], requires_grad=True)
# tensor([[ 1.9991],
#         [-3.3992]], requires_grad=True)
# tensor([[ 1.9990],
#         [-3.3992]], requires_grad=True)
# tensor([[ 1.9992],
#         [-3.3992]], requires_grad=True)
# tensor([[ 1.9992],
#         [-3.3992]], requires_grad=True)
# tensor([[ 1.9992],
#         [-3.3993]], requires_grad=True)
# tensor([[ 1.9993],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9994],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9995],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9996],
#         [-3.3993]], requires_grad=True)
# tensor([[ 1.9997],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9998],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9998],
#         [-3.3994]], requires_grad=True)
# tensor([[ 1.9998],
#         [-3.3993]], requires_grad=True)
# tensor([[ 2.0000],
#         [-3.3994]], requires_grad=True)
# tensor([[ 2.0000],
#         [-3.3995]], requires_grad=True)
# tensor([[ 1.9999],
#         [-3.3992]], requires_grad=True)
# tensor([[ 1.9999],
#         [-3.3994]], requires_grad=True)
# epoch 3, loss 0.000051

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 0.0916, -0.1731], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.2166], grad_fn=<RsubBackward1>)
